# %%
import pandas as pd
from utils import di_ratios

# %%
bmm=pd.read_csv("../data/bmm_clean.csv")

# %%
eurostat=pd.read_csv("../data/eu_stat_processed.csv")
eurostat=eurostat.rename(columns={
    "2021":"#_business_2021",
    "2022":"#_business_2022",
    "2023":"#_business_2023"
})

# %%
merged=bmm.merge(
    right=eurostat,
    how="left",
    on=["country","s_level_segment"]
)

# %%
merged["avg_spend_23"]=merged["fy23"]/merged["#_business_2022"]
merged["avg_spend_24"]=merged["fy24"]/merged["#_business_2023"]

# %%
merged
# Out:
#              country                          level 1  \
# 0            Albania                            Fixed
# 1            Albania                            Fixed
# 2            Albania                            Fixed
# 3            Albania                            Fixed
# 4            Albania                            Fixed
# ...              ...                              ...
# 7800  United Kingdom  Unified Comms and Collaboration
# 7801  United Kingdom  Unified Comms and Collaboration
# 7802  United Kingdom  Unified Comms and Collaboration
# 7803  United Kingdom  Unified Comms and Collaboration
# 7804  United Kingdom  Unified Comms and Collaboration
#
#                        level 2                               level 3  \
# 0          Fixed Data (non-SD)           Cloud Connectivity (non-SD)
# 1          Fixed Data (non-SD)           Cloud Connectivity (non-SD)
# 2          Fixed Data (non-SD)           Cloud Connectivity (non-SD)
# 3          Fixed Data (non-SD)           Cloud Connectivity (non-SD)
# 4          Fixed Data (non-SD)           Cloud Connectivity (non-SD)
# ...                        ...                                   ...
# 7800  UC&C Life Cycle Services  UCC Support and Maintenance Services
# 7801  UC&C Life Cycle Services  UCC Support and Maintenance Services
# 7802  UC&C Life Cycle Services  UCC Support and Maintenance Services
# 7803  UC&C Life Cycle Services  UCC Support and Maintenance Services
# 7804  UC&C Life Cycle Services  UCC Support and Maintenance Services
#
#                                    level 4                    segment  \
# 0              Cloud Connectivity (non-SD)                 SoHo (0-9)
# 1              Cloud Connectivity (non-SD)          Small SME (10-49)
# 2              Cloud Connectivity (non-SD)  Small Corporate (100-249)
# 3              Cloud Connectivity (non-SD)          Large SME (50-99)
# 4              Cloud Connectivity (non-SD)  Large Corporate (500-999)
# ...                                    ...                        ...
# 7800  UCC Support and Maintenance Services  Small Corporate (100-249)
# 7801  UCC Support and Maintenance Services          Large SME (50-99)
# 7802  UCC Support and Maintenance Services  Large Corporate (500-999)
# 7803  UCC Support and Maintenance Services  Large Corporate (250-499)
# 7804  UCC Support and Maintenance Services    Large Corporate (1000+)
#
#      core market orig ccy  orig_ccy_fy23  orig_ccy_fy24  ...       fy26  \
# 0           Core      ALL       0.000000       0.000000  ...   0.000000
# 1           Core      ALL      10.619282      12.700880  ...   0.162260
# 2           Core      ALL      15.500858      17.718191  ...   0.208068
# 3           Core      ALL      10.333905      11.812127  ...   0.138712
# 4           Core      ALL      18.750615      21.647297  ...   0.261692
# ...          ...      ...            ...            ...  ...        ...
# 7800        Core      GBP       7.266739       7.704166  ...  10.048382
# 7801        Core      GBP       4.844493       5.136110  ...   6.698921
# 7802        Core      GBP      23.882154      25.350059  ...  31.764678
# 7803        Core      GBP      23.108676      24.506162  ...  30.650447
# 7804        Core      GBP      25.288669      26.827130  ...  33.574716
#
#            fy27       fy28   region  s_level_segment  #_business_2021  \
# 0      0.000000   0.000000  Cluster            s1-s3     97022.000000
# 1      0.178980   0.196158  Cluster               s4      5608.000000
# 2      0.221304   0.234437  Cluster               s6       774.237199
# 3      0.147536   0.156292  Cluster               s5       452.762801
# 4      0.283528   0.306315  Cluster               s8        46.262534
# ...         ...        ...      ...              ...              ...
# 7800  11.392586  12.745009      EU2               s6     26284.311748
# 7801   7.595057   8.496673      EU2               s5     15370.688252
# 7802  35.168245  38.717173      EU2               s8      2802.339712
# 7803  33.903806  37.291486      EU2               s7      4192.300209
# 7804  37.149561  40.873301      EU2           s9-s11              NaN
#
#       #_business_2022  #_business_2023  avg_spend_23  avg_spend_24
# 0       106132.000000    116097.394653      0.000000      0.000000
# 1         5841.000000      6084.400126      0.000018      0.000021
# 2          824.086212       877.144737      0.000188      0.000202
# 3          481.913788       512.941653      0.000215      0.000230
# 4           48.123671        50.059680      0.003898      0.004326
# ...               ...              ...           ...           ...
# 7800     26388.426775     27003.651933      0.000313      0.000324
# 7801     15431.573225     15791.348067      0.000357      0.000370
# 7802      2811.645394      2900.714066      0.009652      0.009931
# 7803      4206.221510      4339.468243      0.006243      0.006417
# 7804              NaN              NaN           NaN           NaN
#
# [7805 rows x 27 columns]
